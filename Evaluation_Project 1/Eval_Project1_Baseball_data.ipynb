# %% [markdown]
# ### Project Description
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features-
#
# 1. W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2. R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3. AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4. H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5. 2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6. 3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7. HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8. BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9. SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10. SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11. RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12. ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13. ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14. CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15. SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16. SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17. E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
#
# -- Output:
#
# 1. Number of predicted wins (W)

# %%
# importing necessary libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading the dataset from the system
ball_data = pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
ball_data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
ball_data.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# checking for column names and dimensions
print(ball_data.columns)
print()
print("Shape of the Dataset :", ball_data.shape)
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')
#
# Shape of the Dataset : (30, 17)

# %% [markdown]
# The dataset is quite small with only 30 rows and 17 columns.

# %%
# checking the summary statistics
ball_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# **The dataset contains numerical columns(int and float) only.**
# **W(wins) is our target variable.**

# %%
ball_data.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ER    30.0   635.833333   70.140786   478.00   587.2500   644.500   679.25
# ERA   30.0     3.956333    0.454089     2.94     3.6825     4.025     4.22
# CG    30.0     3.466667    2.763473     0.00     1.0000     3.000     5.75
# SHO   30.0    11.300000    4.120177     4.00     9.0000    12.000    13.00
# SV    30.0    43.066667    7.869335    28.00    37.2500    42.000    46.75
# E     30.0    94.333333   13.958889    75.00    86.0000    91.000    96.75
#
#          max
# W     100.00
# R     891.00
# AB   5649.00
# H    1515.00
# 2B    308.00
# 3B     49.00
# HR    232.00
# BB    570.00
# SO   1518.00
# SB    134.00
# RA    844.00
# ER    799.00
# ERA     5.04
# CG     11.00
# SHO    21.00
# SV     62.00
# E     126.00

# %% [markdown]
# The target variable W has 30 rows, the average number of wins is approximately 80.97. The standard deviation is around 10.45, indicating that the number of wins varies by about 10.45 wins from the mean. The minimum and maximum values for wins are 63 and 100, respectively, and the median (50th percentile) value is 81, which means half of the teams had more than 81 wins, and half had fewer.

# %%
# checking for null values
ball_data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Dataset has no null values.

# %%
# checking the frequency of wins
plt.figure(figsize=(8,6))
sns.histplot(data=ball_data, x='W', bins=10)
plt.show()

# %%
# number of unique values in columns
ball_data.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
plt.figure(figsize=(12,12))
print("\n")
print("Distribution of Various Features")
print("\n")

for i, col in enumerate(ball_data.columns):
    plt.subplot(6, 3, i+1)
    sns.histplot(data=ball_data, x=ball_data[col], kde=True)
    plt.ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# Distribution of Various Features

# %%
# box plots for each feature to visualize the distribution of data

plt.figure(figsize=(16,20))
print("\n")
print("Distribution of Various Features")
print("\n")

for i, col in enumerate(ball_data.columns):
    plt.subplot(6, 3, i+1)
    sns.boxplot(data=ball_data, y=ball_data[col])
    plt.ylabel(col)

plt.tight_layout()
plt.show()
# Out:
# Distribution of Various Features

# %% [markdown]
# Outliers are present in E,SV,SHO,ERA and R columns.

# %%
# plotting regression plots

# Set the figure size
plt.figure(figsize=(15, 15))

# Plot regression plot for each input feature against 'W'
for i, feature in enumerate(input_features):
    plt.subplot(6, 3, i+1)
    sns.regplot(x='W', y=feature, data=ball_data, scatter_kws={"s": 10})
    plt.xlabel('Number of Wins (W)')
    plt.ylabel(feature)
    plt.title(f'Regression Plot: W vs. {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Positive slope-- SHO,SV,BB,2B,HR has positive slopes indicating that their value increases when the number of wins increase.
# 2. Negative slope-- RA,ER,ERA,3B have negative slope indicating that their value decreases when the the number of wins decrease.
# 3. Remaining features (E,SO,SB,AB,H,CG,R) has a constant slope.

# %%
# plotting heatmap
plt.figure(figsize = (16,10))
sns.heatmap(ball_data.corr(), annot = True)
plt.show()

# %%
# correlation between input features and the target variable
ball_data.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# 1. The features with high negative correlations with the number of wins (W) are ERA, RA, and ER, which are pitching-related statistics. This means that as these pitching statistics increase, the number of wins tends to decrease.
#
# 2. The features with high positive correlations with the number of wins (W) are SV, BB, SHO, R, and 2B, which are related to saves, walks, shutouts, runs scored, and doubles, respectively. This means that as these statistics increase, the number of wins tends to increase.
#
# 3. Other features have relatively weaker correlations with the number of wins.

# %%
# checking for skewness in data
ball_data.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# RA     0.045734
# W      0.047089
# ERA    0.053331
# ER     0.058710
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# H      0.670254
# CG     0.736845
# E      0.890132
# R      1.200786
# dtype: float64

# %%
# For regression, average price is the target column

X= ball_data.drop('W', axis=1)
y = ball_data['W']

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler

# scaling the dataset
scaler = StandardScaler()
X = scaler.fit_transform(X)

# splitting data into train and tests set
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=42)

print('X_train shape', X_train.shape)
print('X_test shape', X_test.shape)
print('y_train shape', y_train.shape)
print('y_test shape', y_test.shape)
# Out:
# X_train shape (21, 16)
# X_test shape (9, 16)
# y_train shape (21,)
# y_test shape (9,)

# %%
# importing libraries
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

models = [('Linear Regression', LinearRegression()),
          ('RFR', RandomForestRegressor()),('Support Vector_reg', SVR()),
          ('Tree_reg', DecisionTreeRegressor())]

predictions = []
for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    predictions.append((name, y_pred))
    
# Plotting the predicted vs actual values
for name, y_pred in predictions:
    plt.figure(figsize=(4,4))
    plt.scatter(y_test, y_pred)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title(name)
    plt.xticks(rotation=45)
    plt.show()

# %%
metrics = []
for name, y_pred in predictions:
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    metrics.append((name, r2, mse, rmse, mae))

# Creating metrics dataframe
metrics_df = pd.DataFrame(metrics, columns=['Model_name', 'R2_score', 'Mean_Squared_Error',
                                            'Root_Mean_Squared_Error', 'Mean_Absolute_Error'])

metrics_df
# Out:
#            Model_name  R2_score  Mean_Squared_Error  Root_Mean_Squared_Error  \
# 0   Linear Regression  0.769258           31.073232                 5.574337
# 1                 RFR  0.665545           45.040000                 6.711185
# 2  Support Vector_reg  0.120340          118.460907                10.883975
# 3            Tree_reg  0.557756           59.555556                 7.717225
#
#    Mean_Absolute_Error
# 0             4.699674
# 1             6.088889
# 2             9.140982
# 3             7.111111

# %% [markdown]
# 1. The Linear Regression model has the highest R2 score (0.769), indicating that it fits the data relatively well.
# 2. The Support Vector Regression model has the lowest performance, with a very low R2 score (0.12) and higher errors (higher MSE, RMSE, and MAE).

# %%
# using cross val score on the other thre regressors
for name, model in models:
    cv_score = cross_val_score(model, X, y, cv=5)
    print('Model :', name)
    print('cv_score :',cv_score)
    print('Mean Score', cv_score.mean())
    print("Diffrenece between Mean CV Score and R2 score", (r2_score(y_test,y_pred)-cv_score.mean()))
    print("\n")
# Out:
# Model : Linear Regression
# cv_score : [ 0.71136471 -2.21099237  0.38808753  0.73556937  0.5797478 ]
# Mean Score 0.04075540667455839
# Diffrenece between Mean CV Score and R2 score 0.5170003689029994
#
#
# Model : RFR
# cv_score : [-0.37403197 -2.86152672  0.2123115   0.35486342  0.69433728]
# Mean Score -0.394809297671752
# Diffrenece between Mean CV Score and R2 score 0.9525650732493097
#
#
# Model : Support Vector_reg
# cv_score : [-0.10470568 -0.91313375 -0.26729206 -0.60338599 -0.00134093]
# Mean Score -0.37797168143530036
# Diffrenece between Mean CV Score and R2 score 0.9357274570128581
#
#
# Model : Tree_reg
# cv_score : [-0.169627   -9.0648855  -0.49200305  0.35949765  0.55088757]
# Mean Score -1.7632260643378141
# Diffrenece between Mean CV Score and R2 score 2.3209818399153717

# %% [markdown]
# 1. For the Linear Regression model, the difference of around 0.52. This suggests that the model's performance on the cross-validation folds is consistent with the R2 score.
# 2. For the Random Forest Regression (RFR) model, there is a larger difference of approximately 0.95 between the mean cross-validation score and the R2 score. This suggests that the RFR model might be overfitting, as its performance on the training data is significantly better than on unseen data.
# 3. Similarly, for the Support Vector Regression model and the Tree Regression model, there are noticeable differences between the mean cross-validation scores and the R2 scores. This indicates that these models might also have issues with overfitting or generalization to unseen data.

# %% [markdown]
# **Among the models, the "Linear Regression" model appears to be the most balanced and promising choice based on the cross-validation (CV) score, the difference between mean CV score and R2 score, and the R2 score itself.**

# %%
# Hyperparameter grid for Linear Regression
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False]
}

# Create GridSearchCV object
grid_search = GridSearchCV(LinearRegression(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X, y)

# Print best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'fit_intercept': True, 'normalize': False}

# %%
# final model
final = LinearRegression(fit_intercept=True, normalize=False)
final.fit(X_train,y_train)
final_pred = final.predict(X_test)
print("R2_score :", r2_score(y_test,final_pred))
# Out:
# R2_score : 0.7692581763754502

# %%
# saving the model
import joblib
joblib.dump(final, "Baseball_wins.pkl")
# Out:
# ['Baseball_wins.pkl']

# %%
# predicting on the X with the saved model
#loading the aved model
model = joblib.load("Baseball_wins.pkl")

# prediction
prediction = model.predict(X)
prediction[:10]
# Out:
# array([96.08663729, 84.27677082, 81.55616692, 74.35987699, 72.71637143,
#        93.27170928, 86.15569005, 81.16498896, 90.39963826, 78.8970924 ])

# %%
# comparing actual values and predicted values
pred = pd.DataFrame({'predicted':prediction, 'actual':y})
pred.head(10)
# Out:
#    predicted  actual
# 0  96.086637      95
# 1  84.276771      83
# 2  81.556167      81
# 3  74.359877      76
# 4  72.716371      74
# 5  93.271709      93
# 6  86.155690      87
# 7  81.164989      81
# 8  90.399638      80
# 9  78.897092      78

# %% [markdown]
# In conclusion, this analysis explored a dataset containing baseball team statistics to predict the number of wins (W) for each team. The dataset was preprocessed by checking for null values, examining the summary statistics, and visualizing the distributions and correlations between features. Outliers were identified in certain columns, and regression plots were created to visualize the relationships between the target variable (W) and input features.
#
# Four regression models—Linear Regression, Random Forest Regression, Support Vector Regression, and Tree Regression—were trained and evaluated using various performance metrics. The Linear Regression model demonstrated the highest R-squared score of approximately 0.77, indicating a relatively good fit to the data. Cross-validation scores were also analyzed for the models, and discrepancies between mean cross-validation scores and R-squared scores were observed, suggesting potential issues with overfitting for some models.
#
# To improve the Linear Regression model, hyperparameter tuning was performed using GridSearchCV. The best hyperparameters were found to be 'fit_intercept=True' and 'normalize=False'. The tuned Linear Regression model achieved an R-squared score of approximately 0.77 on the test set.
#
# The final model was saved using the 'joblib' library, allowing for predictions on new data. The model was applied to the dataset to make predictions on the number of wins. A comparison between predicted and actual values was presented, showing the model's performance.
#
# In conclusion, the Linear Regression model, after hyperparameter tuning, appeared to be the most promising among the tested models for predicting baseball team wins based on the given dataset.
